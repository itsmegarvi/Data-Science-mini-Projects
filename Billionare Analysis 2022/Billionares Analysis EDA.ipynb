# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter

# %%
df = pd.read_csv("2022_forbes_billionaires.csv",index_col="rank")
df
# Out:
#       Unnamed: 0                       name networth  age        country  \
# rank
# 1              0                 Elon Musk    $219 B   50  United States
# 2              1                Jeff Bezos    $171 B   58  United States
# 3              2  Bernard Arnault & family    $158 B   73         France
# 4              3                Bill Gates    $129 B   66  United States
# 5              4            Warren Buffett    $118 B   91  United States
# ...          ...                        ...      ...  ...            ...
# 2578        2595    Jorge Gallardo Ballart      $1 B   80          Spain
# 2578        2596              Nari Genomal      $1 B   82    Philippines
# 2578        2597            Ramesh Genomal      $1 B   71    Philippines
# 2578        2598            Sunder Genomal      $1 B   68    Philippines
# 2578        2599     Horst-Otto Gerberding      $1 B   69        Germany
#
#                       source                industry
# rank
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# name          0
# networth      0
# age           0
# country       0
# source        0
# industry      0
# dtype: int64

# %%
df = df.dropna(axis=1)

# %%
df = df.drop(df.columns[0],axis=1)
df
# Out:
#                            name networth  age        country  \
# rank
# 1                    Elon Musk    $219 B   50  United States
# 2                   Jeff Bezos    $171 B   58  United States
# 3     Bernard Arnault & family    $158 B   73         France
# 4                   Bill Gates    $129 B   66  United States
# 5               Warren Buffett    $118 B   91  United States
# ...                         ...      ...  ...            ...
# 2578    Jorge Gallardo Ballart      $1 B   80          Spain
# 2578              Nari Genomal      $1 B   82    Philippines
# 2578            Ramesh Genomal      $1 B   71    Philippines
# 2578            Sunder Genomal      $1 B   68    Philippines
# 2578     Horst-Otto Gerberding      $1 B   69        Germany
#
#                       source                industry
# rank
# 1              Tesla, SpaceX             Automotive
# 2                     Amazon             Technology
# 3                       LVMH       Fashion & Retail
# ...

# %%
df.head()
# Out:
#                            name networth  age        country  \
# rank
# 1                    Elon Musk    $219 B   50  United States
# 2                   Jeff Bezos    $171 B   58  United States
# 3     Bernard Arnault & family    $158 B   73         France
# 4                   Bill Gates    $129 B   66  United States
# 5               Warren Buffett    $118 B   91  United States
#
#                   source                industry
# rank
# 1          Tesla, SpaceX             Automotive
# 2                 Amazon             Technology
# 3                   LVMH       Fashion & Retail
# 4              Microsoft             Technology
# 5     Berkshire Hathaway  Finance & Investments

# %% [markdown]
# 5 richest billionaires

# %%
df.dtypes
# Out:
# name        object
# networth    object
# age          int64
# country     object
# source      object
# industry    object
# dtype: object

# %%
s = df.loc[df["age"]<=45]
s
# Out:
#                        name networth  age        country  \
# rank
# 15         Mark Zuckerberg   $67.3 B   37  United States
# 19          Changpeng Zhao     $65 B   44         Canada
# 25            Zhang Yiming     $50 B   38          China
# 60       Sam Bankman-Fried     $24 B   30  United States
# 66        Guillaume Pousaz     $23 B   40    Switzerland
# ...                     ...      ...  ...            ...
# 2448    Franziska Wuerbser    $1.1 B   34        Germany
# 2448         Vlad Yatsenko    $1.1 B   38        Ukraine
# 2578         Johanna Braun      $1 B   42        Germany
# 2578  Karl Friedrich Braun      $1 B   39        Germany
# 2578           Doug Clarke      $1 B   41      Australia
#
#                        source                industry
# rank
# 15                   Facebook             Technology
# 19    cryptocurrency exchange  Finance & Investments
# 25                     TikTok  Media & Entertainment
# ...

# %% [markdown]
# Only 201 people are under the age of 46 out of 2600

# %%
nw = df["networth"].str.rstrip(" B").str.lstrip("$")
nw = [eval(i) for i in nw]
#nw[1].rstrip(" B").lstrip("$")
df["networth"] = nw
df
# Out:
#                            name  networth  age        country  \
# rank
# 1                    Elon Musk      219.0   50  United States
# 2                   Jeff Bezos      171.0   58  United States
# 3     Bernard Arnault & family      158.0   73         France
# 4                   Bill Gates      129.0   66  United States
# 5               Warren Buffett      118.0   91  United States
# ...                         ...       ...  ...            ...
# 2578    Jorge Gallardo Ballart        1.0   80          Spain
# 2578              Nari Genomal        1.0   82    Philippines
# 2578            Ramesh Genomal        1.0   71    Philippines
# 2578            Sunder Genomal        1.0   68    Philippines
# 2578     Horst-Otto Gerberding        1.0   69        Germany
#
#                       source                industry
# rank
# 1              Tesla, SpaceX             Automotive
# 2                     Amazon             Technology
# ...

# %%
worth = df.loc[df["networth"]<2]
worth
# Out:
#                          name  networth  age      country  \
# rank
# 1579                 Anu Aga        1.9   79        India
# 1579             Joy Alukkas        1.9   65        India
# 1579          Sezai Bacaksiz        1.9   72       Turkey
# 1579              Baokun Bai        1.9   52        China
# 1579      Acharya Balkrishna        1.9   49        India
# ...                       ...       ...  ...          ...
# 2578  Jorge Gallardo Ballart        1.0   80        Spain
# 2578            Nari Genomal        1.0   82  Philippines
# 2578          Ramesh Genomal        1.0   71  Philippines
# 2578          Sunder Genomal        1.0   68  Philippines
# 2578   Horst-Otto Gerberding        1.0   69      Germany
#
#                       source                     industry
# rank
# 1579             engineering  Construction & Engineering
# 1579                 jewelry            Fashion & Retail
# 1579             diversified                 Diversified
# ...

# %% [markdown]
# Of the 2600 billionaires 1022 are not multi-billionaires

# %%
worthb = df.loc[df["networth"]>=2]
worthb
# Out:
#                            name  networth  age        country  \
# rank
# 1                    Elon Musk      219.0   50  United States
# 2                   Jeff Bezos      171.0   58  United States
# 3     Bernard Arnault & family      158.0   73         France
# 4                   Bill Gates      129.0   66  United States
# 5               Warren Buffett      118.0   91  United States
# ...                         ...       ...  ...            ...
# 1513                Zhongyi Wu        2.0   48          China
# 1513                 Zhihan Xu        2.0   49          China
# 1513                   Yan Zhi        2.0   49          China
# 1513              Michael Ying        2.0   72      Hong Kong
# 1513               Yuan Liping        2.0   51         Canada
#
#                   source                industry
# rank
# 1          Tesla, SpaceX             Automotive
# 2                 Amazon             Technology
# 3                   LVMH       Fashion & Retail
# ...

# %% [markdown]
# Of the 2600 billionaires 1578 are multi-billionaires

# %%
countries = df["country"].unique()
len(countries)
# Out:
# 75

# %% [markdown]
# The 2600 billionaires originate from 75 different countries

# %%
industries = df["industry"].unique()
len(industries)
# Out:
# 18

# %% [markdown]
# The billionaires became rich with 18 different industries

# %%
s = df["country"]
s
# Out:
# rank
# 1       United States
# 2       United States
# 3              France
# 4       United States
# 5       United States
#             ...
# 2578            Spain
# 2578      Philippines
# 2578      Philippines
# 2578      Philippines
# 2578          Germany
# Name: country, Length: 2600, dtype: object

# %%
# d = dict(list((Counter(df["country"])).items())[:10])
d = Counter(df["country"])
# myKeys = list(d.keys())
# myKeys.sort()                      // Failed attempts of a simple task
# sd = {i: d[i] for i in myKeys}
d = dict(sorted(d.items(), key=lambda x: x[1],reverse=True))  # sorting the dict by its values
d = dict(list(d.items())[:5])
d
# Out:
# {'United States': 719,
#  'China': 515,
#  'India': 161,
#  'Germany': 130,
#  'Russia': 81}

# %%
c = list(d.keys())
values = list(d.values())

# %%
plt.bar(range(len(d)),values, tick_label= c)
# plt.xlabel("Top 5 countries")
plt.ylabel("No. od Billionaires")
plt.title("Top 5 Countries with Billionares")
plt.show()

# %% [markdown]
# This graph above shows us the 5 countries with most number of billionares

# %%
i = Counter(df["industry"])
i = dict(sorted(d.items(), key=lambda x: x[1],reverse=True))  # sorting the dict by its values
i = dict(list(d.items()))
i
# Out:
# {'United States': 719,
#  'China': 515,
#  'India': 161,
#  'Germany': 130,
#  'Russia': 81}

# %%
ins = list(i.keys())
v = list(i.values())

# %%
plt.figure(figsize=(18,10))
plt.xticks(rotation=45)
plt.bar(range(len(i)),v, tick_label= ins)
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# Distribution of Billionaires across different industries
