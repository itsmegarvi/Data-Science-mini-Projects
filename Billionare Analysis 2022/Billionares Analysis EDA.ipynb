# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Downloads/2022_forbes_billionaires.csv",index_col="rank")
df
# Out:
#                            name networth  age        country  \
# rank
# 1                    Elon Musk    $219 B   50  United States
# 2                   Jeff Bezos    $171 B   58  United States
# 3     Bernard Arnault & family    $158 B   73         France
# 4                   Bill Gates    $129 B   66  United States
# 5               Warren Buffett    $118 B   91  United States
# ...                         ...      ...  ...            ...
# 2578    Jorge Gallardo Ballart      $1 B   80          Spain
# 2578              Nari Genomal      $1 B   82    Philippines
# 2578            Ramesh Genomal      $1 B   71    Philippines
# 2578            Sunder Genomal      $1 B   68    Philippines
# 2578     Horst-Otto Gerberding      $1 B   69        Germany
#
#                       source                industry  Unnamed: 7
# rank
# 1              Tesla, SpaceX             Automotive          NaN
# 2                     Amazon             Technology          NaN
# 3                       LVMH       Fashion & Retail          NaN
# 4                  Microsoft             Technology          NaN
# 5         Berkshire Hathaway  Finance & Investments          NaN
# ...                      ...                     ...         ...
# 2578         pharmaceuticals             Healthcare          NaN
# 2578                 apparel       Fashion & Retail          NaN
# 2578                 apparel       Fashion & Retail          NaN
# 2578                garments       Fashion & Retail          NaN
# 2578  flavors and fragrances        Food & Beverage          NaN
#
# [2600 rows x 7 columns]

# %%
df.isnull().sum()
# Out:
# name             0
# networth         0
# age              0
# country          0
# source           0
# industry         0
# Unnamed: 7    2600
# dtype: int64

# %%
df = df.dropna(axis=1)

# %%
df
# Out:
#                            name networth  age        country  \
# rank
# 1                    Elon Musk    $219 B   50  United States
# 2                   Jeff Bezos    $171 B   58  United States
# 3     Bernard Arnault & family    $158 B   73         France
# 4                   Bill Gates    $129 B   66  United States
# 5               Warren Buffett    $118 B   91  United States
# ...                         ...      ...  ...            ...
# 2578    Jorge Gallardo Ballart      $1 B   80          Spain
# 2578              Nari Genomal      $1 B   82    Philippines
# 2578            Ramesh Genomal      $1 B   71    Philippines
# 2578            Sunder Genomal      $1 B   68    Philippines
# 2578     Horst-Otto Gerberding      $1 B   69        Germany
#
#                       source                industry
# rank
# 1              Tesla, SpaceX             Automotive
# 2                     Amazon             Technology
# 3                       LVMH       Fashion & Retail
# 4                  Microsoft             Technology
# 5         Berkshire Hathaway  Finance & Investments
# ...                      ...                     ...
# 2578         pharmaceuticals             Healthcare
# 2578                 apparel       Fashion & Retail
# 2578                 apparel       Fashion & Retail
# 2578                garments       Fashion & Retail
# 2578  flavors and fragrances        Food & Beverage
#
# [2600 rows x 6 columns]

# %%
countries = df["country"].unique()
len(countries)
# Out:
# 75

# %% [markdown]
# The 2600 billionaires originate from 75 different countries

# %%
industries = df["industry"].unique()
len(industries)
# Out:
# 18

# %% [markdown]
# The billionaires became rich with 18 different industries

# %%
s = df["country"].value_counts()[:10]
s
# Out:
# United States    719
# China            515
# India            161
# Germany          130
# Russia            81
# Hong Kong         67
# Canada            64
# Brazil            60
# Italy             52
# Taiwan            51
# Name: country, dtype: int64
